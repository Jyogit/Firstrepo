# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "http://www.hubertiming.com/results/2017GPTR10K"
html = urlopen(url)

# %%
soup = BeautifulSoup(html,'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
#Get the title
title = soup.title
print(title)
# Out:
# <title>2017 Intel Great Place to Run 10K \ Urban Clash Games Race Results</title>

# %%
# Print out the text
text = soup.get_text()
#print(text)

# %% [markdown]
# You can use the find_all() method of soup to extract useful html tags within
# a webpage. Examples of useful tags include < a > for hyperlinks, < table > for tables, < tr > for table rows, < th > for table headers, and < td > for table cells.
# The code below shows how to extract all the hyperlinks within the webpage.

# %%
soup.find_all('a')
# Out:
# [<a class="btn btn-primary btn-lg" href="/results/2017GPTR" role="button" style="margin: 0px 0px 5px 5px">5K</a>,
#  <a href="https://www.hubertiming.com/">Huber Timing Home</a>,
#  <a href="#individual">Individual Results</a>,
#  <a href="#team">Team Results</a>,
#  <a href="mailto:timing@hubertiming.com">timing@hubertiming.com</a>,
#  <a href="#tabs-1" style="font-size: 18px">Results</a>,
#  <a name="individual"></a>,
#  <a name="team"></a>,
#  <a href="https://www.hubertiming.com/"><img height="65" src="/sites/all/themes/hubertiming/images/clockWithFinishSign_small.png" width="50"/>Huber Timing</a>,
#  <a href="https://facebook.com/hubertiming/"><img src="/results/FB-f-Logo__blue_50.png"/></a>]

# %%
all_links = soup.find_all('a')
for link in all_links:
    print(link.get("href"))
# Out:
# /results/2017GPTR
# https://www.hubertiming.com/
# #individual
# #team
# mailto:timing@hubertiming.com
# #tabs-1
# None
# None
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/

# %% [markdown]
# To print out table rows only, pass the 'tr' argument in soup.find_all()

# %%
# Print the first 10 rows for sanity check
rows = soup.find_all('tr')
print(rows[:10])
# Out:
# [<tr><td>Finishers:</td><td>577</td></tr>, <tr><td>Male:</td><td>414</td></tr>, <tr><td>Female:</td><td>163</td></tr>, <tr class="header">
# <th>Place</th>
# <th>Bib</th>
# <th>Name</th>
# <th>Gender</th>
# <th>City</th>
# <th>State</th>
# <th>Chip Time</th>
# <th>Chip Pace</th>
# <th>Gender Place</th>
# <th>Age Group</th>
# <th>Age Group Place</th>
# <th>Time to Start</th>
# <th>Gun Time</th>
# <th>Team</th>
# </tr>, <tr>
# <td>1</td>
# <td>814</td>
# <td>JARED WILSON</td>
# <td>M</td>
# <td>TIGARD</td>
# <td>OR</td>
# <td>00:36:21</td>
# <td>05:51</td>
# <td>1 of 414</td>
# <td>M 36-45</td>
# <td>1 of 152</td>
# <td>00:00:03</td>
# <td>00:36:24</td>
# <td></td>
# </tr>, <tr>
# <td>2</td>
# <td>573</td>
# <td>NATHAN A SUSTERSIC</td>
# <td>M</td>
# <td>PORTLAND</td>
# <td>OR</td>
# <td>00:36:42</td>
# <td>05:55</td>
# <td>2 of 414</td>
# <td>M 26-35</td>
# <td>1 of 154</td>
# <td>00:00:03</td>
# <td>00:36:45</td>
# <td>INTEL TEAM F</td>
# </tr>, <tr>
# <td>3</td>
# <td>687</td>
# ...

# %%
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td>14TH</td>, <td>INTEL TEAM M</td>, <td>04:43:23</td>, <td>00:58:59 - DANIELLE CASILLAS</td>, <td>01:02:06 - RAMYA MERUVA</td>, <td>01:17:06 - PALLAVI J SHINDE</td>, <td>01:25:11 - NALINI MURARI</td>]
# bs4.element.ResultSet

# %% [markdown]
# The output above shows that each row is printed with html tags embedded in each
# row. This is not what you want. You can use remove the html tags using Beautiful
# Soup or regular expressions.
#
# The easiest way to remove html tags is to use Beautiful Soup, and it takes just
# one line of code to do this. Pass the string of interest into BeautifulSoup()
# and use the get_text() method to extract the text without html tags.

# %%
str_cells = str(row_td)
cleantext = BeautifulSoup(str_cells,"lxml").get_text()
print(cleantext)
# Out:
# [14TH, INTEL TEAM M, 04:43:23, 00:58:59 - DANIELLE CASILLAS, 01:02:06 - RAMYA MERUVA, 01:17:06 - PALLAVI J SHINDE, 01:25:11 - NALINI MURARI]

# %%
list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    #clean = re.compile('<.*?>')
    clean2 = BeautifulSoup(str_cells,"lxml").get_text()
    #clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [14TH, INTEL TEAM M, 04:43:23, 00:58:59 - DANIELLE CASILLAS, 01:02:06 - RAMYA MERUVA, 01:17:06 - PALLAVI J SHINDE, 01:25:11 - NALINI MURARI]
# str

# %%
print(list_rows[:10])
# Out:
# ['[Finishers:, 577]', '[Male:, 414]', '[Female:, 163]', '[]', '[1, 814, JARED WILSON, M, TIGARD, OR, 00:36:21, 05:51, 1 of 414, M 36-45, 1 of 152, 00:00:03, 00:36:24, ]', '[2, 573, NATHAN A SUSTERSIC, M, PORTLAND, OR, 00:36:42, 05:55, 2 of 414, M 26-35, 1 of 154, 00:00:03, 00:36:45, INTEL TEAM F]', '[3, 687, FRANCISCO MAYA, M, PORTLAND, OR, 00:37:44, 06:05, 3 of 414, M 46-55, 1 of 64, 00:00:04, 00:37:48, ]', '[4, 623, PAUL MORROW, M, BEAVERTON, OR, 00:38:34, 06:13, 4 of 414, M 36-45, 2 of 152, 00:00:03, 00:38:37, ]', '[5, 569, DEREK G OSBORNE, M, HILLSBORO, OR, 00:39:21, 06:20, 5 of 414, M 26-35, 2 of 154, 00:00:03, 00:39:24, INTEL TEAM F]', '[6, 642, JONATHON TRAN, M, PORTLAND, OR, 00:39:49, 06:25, 6 of 414, M 18-25, 1 of 34, 00:00:06, 00:39:55, ]']

# %%
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                  [Finishers:, 577]
# 1                                       [Male:, 414]
# 2                                     [Female:, 163]
# 3                                                 []
# 4  [1, 814, JARED WILSON, M, TIGARD, OR, 00:36:21...
# 5  [2, 573, NATHAN A SUSTERSIC, M, PORTLAND, OR, ...
# 6  [3, 687, FRANCISCO MAYA, M, PORTLAND, OR, 00:3...
# 7  [4, 623, PAUL MORROW, M, BEAVERTON, OR, 00:38:...
# 8  [5, 569, DEREK G OSBORNE, M, HILLSBORO, OR, 00...
# 9  [6, 642, JONATHON TRAN, M, PORTLAND, OR, 00:39...

# %%
df1 = df[0].str.split(',', expand=True)
df1.head(10)
# Out:
#             0      1                    2     3           4     5          6   \
# 0  [Finishers:   577]                 None  None        None  None       None
# 1       [Male:   414]                 None  None        None  None       None
# 2     [Female:   163]                 None  None        None  None       None
# 3           []   None                 None  None        None  None       None
# 4           [1    814         JARED WILSON     M      TIGARD    OR   00:36:21
# 5           [2    573   NATHAN A SUSTERSIC     M    PORTLAND    OR   00:36:42
# 6           [3    687       FRANCISCO MAYA     M    PORTLAND    OR   00:37:44
# 7           [4    623          PAUL MORROW     M   BEAVERTON    OR   00:38:34
# 8           [5    569      DEREK G OSBORNE     M   HILLSBORO    OR   00:39:21
# 9           [6    642        JONATHON TRAN     M    PORTLAND    OR   00:39:49
#
#        7          8         9          10         11         12  \
# ...

# %% [markdown]
# This looks much better, but there is still work to do. The dataframe has unwanted square brackets surrounding each row. You can use the strip() method to remove the opening square bracket on column "0."

# %%
df1[0]=df1[0].str.strip('[')
df1.head(10)
# Out:
#            0      1                    2     3           4     5          6   \
# 0  Finishers:   577]                 None  None        None  None       None
# 1       Male:   414]                 None  None        None  None       None
# 2     Female:   163]                 None  None        None  None       None
# 3           ]   None                 None  None        None  None       None
# 4           1    814         JARED WILSON     M      TIGARD    OR   00:36:21
# 5           2    573   NATHAN A SUSTERSIC     M    PORTLAND    OR   00:36:42
# 6           3    687       FRANCISCO MAYA     M    PORTLAND    OR   00:37:44
# 7           4    623          PAUL MORROW     M   BEAVERTON    OR   00:38:34
# 8           5    569      DEREK G OSBORNE     M   HILLSBORO    OR   00:39:21
# 9           6    642        JONATHON TRAN     M    PORTLAND    OR   00:39:49
#
#        7          8         9          10         11         12  \
# ...

# %%
#The table is missing table headers. 
#You can use the find_all() method to get the table headers.
col_labels = soup.find_all('th')

# %% [markdown]
# Similar to table rows, you can use Beautiful Soup to extract text in between html tags for table headers.

# %%
all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ['[Place, Bib, Name, Gender, City, State, Chip Time, Chip Pace, Gender Place, Age Group, Age Group Place, Time to Start, Gun Time, Team]']

# %%
df2 = pd.DataFrame(all_header)
df2.head()
# Out:
#                                                    0
# 0  [Place, Bib, Name, Gender, City, State, Chip T...

# %%
#Similarly, you can split column "0" into multiple columns 
#at the comma position for all rows.
df3 = df2[0].str.split(',', expand = True)
df3.head()
# Out:
#        0     1      2        3      4       5           6           7   \
# 0  [Place   Bib   Name   Gender   City   State   Chip Time   Chip Pace
#
#               8           9                 10              11         12  \
# 0   Gender Place   Age Group   Age Group Place   Time to Start   Gun Time
#
#        13
# 0   Team]

# %%
#Similarly, you can split column "0" into 
#multiple columns at the comma position for all rows.
frames = [df3, df1]
df4 = pd.concat(frames)
df4.head(10)
# Out:
#            0      1                    2        3           4       5   \
# 0      [Place    Bib                 Name   Gender        City   State
# 0  Finishers:   577]                 None     None        None    None
# 1       Male:   414]                 None     None        None    None
# 2     Female:   163]                 None     None        None    None
# 3           ]   None                 None     None        None    None
# 4           1    814         JARED WILSON        M      TIGARD      OR
# 5           2    573   NATHAN A SUSTERSIC        M    PORTLAND      OR
# 6           3    687       FRANCISCO MAYA        M    PORTLAND      OR
# 7           4    623          PAUL MORROW        M   BEAVERTON      OR
# 8           5    569      DEREK G OSBORNE        M   HILLSBORO      OR
#
#            6           7              8           9                 10  \
# 0   Chip Time   Chip Pace   Gender Place   Age Group   Age Group Place
# ...

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#        [Place    Bib   Name   Gender   City   State   Chip Time   Chip Pace  \
# 0      [Place    Bib   Name   Gender   City   State   Chip Time   Chip Pace
# 0  Finishers:   577]   None     None   None    None        None        None
# 1       Male:   414]   None     None   None    None        None        None
# 2     Female:   163]   None     None   None    None        None        None
# 3           ]   None   None     None   None    None        None        None
#
#     Gender Place   Age Group   Age Group Place   Time to Start   Gun Time  \
# 0   Gender Place   Age Group   Age Group Place   Time to Start   Gun Time
# 0           None        None              None            None       None
# 1           None        None              None            None       None
# 2           None        None              None            None       None
# 3           None        None              None            None       None
#
#     Team]
# 0   Team]
# 0    None
# 1    None
# 2    None
# ...

# %%
df5.info()
df5.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 597 entries, 0 to 595
# Data columns (total 14 columns):
# [Place              597 non-null object
#  Bib                596 non-null object
#  Name               593 non-null object
#  Gender             593 non-null object
#  City               593 non-null object
#  State              593 non-null object
#  Chip Time          593 non-null object
#  Chip Pace          578 non-null object
#  Gender Place       578 non-null object
#  Age Group          578 non-null object
#  Age Group Place    578 non-null object
#  Time to Start      578 non-null object
#  Gun Time           578 non-null object
#  Team]              578 non-null object
# dtypes: object(14)
# memory usage: 70.0+ KB
# (597, 14)

# %% [markdown]
# The table has 597 rows and 14 columns.
# You can drop all rows with any missing values.

# %%
df6 = df5.dropna(axis = 0,how='any')

# %%
df7 = df6.drop(df6.index[0])
df7.head()
# Out:
#   [Place   Bib                 Name  Gender        City  State  Chip Time  \
# 4      1   814         JARED WILSON       M      TIGARD     OR   00:36:21
# 5      2   573   NATHAN A SUSTERSIC       M    PORTLAND     OR   00:36:42
# 6      3   687       FRANCISCO MAYA       M    PORTLAND     OR   00:37:44
# 7      4   623          PAUL MORROW       M   BEAVERTON     OR   00:38:34
# 8      5   569      DEREK G OSBORNE       M   HILLSBORO     OR   00:39:21
#
#    Chip Pace  Gender Place  Age Group  Age Group Place  Time to Start  \
# 4      05:51      1 of 414    M 36-45         1 of 152       00:00:03
# 5      05:55      2 of 414    M 26-35         1 of 154       00:00:03
# 6      06:05      3 of 414    M 46-55          1 of 64       00:00:04
# 7      06:13      4 of 414    M 36-45         2 of 152       00:00:03
# 8      06:20      5 of 414    M 26-35         2 of 154       00:00:03
#
#     Gun Time           Team]
# 4   00:36:24               ]
# 5   00:36:45   INTEL TEAM F]
# ...

# %%
df7.rename(columns={'[Place':'Place'},inplace=True)
df7.rename(columns={' Team]':'Team'},inplace = True)
df7.head()
# Out:
#   Place   Bib                 Name  Gender        City  State  Chip Time  \
# 4     1   814         JARED WILSON       M      TIGARD     OR   00:36:21
# 5     2   573   NATHAN A SUSTERSIC       M    PORTLAND     OR   00:36:42
# 6     3   687       FRANCISCO MAYA       M    PORTLAND     OR   00:37:44
# 7     4   623          PAUL MORROW       M   BEAVERTON     OR   00:38:34
# 8     5   569      DEREK G OSBORNE       M   HILLSBORO     OR   00:39:21
#
#    Chip Pace  Gender Place  Age Group  Age Group Place  Time to Start  \
# 4      05:51      1 of 414    M 36-45         1 of 152       00:00:03
# 5      05:55      2 of 414    M 26-35         1 of 154       00:00:03
# 6      06:05      3 of 414    M 46-55          1 of 64       00:00:04
# 7      06:13      4 of 414    M 36-45         2 of 152       00:00:03
# 8      06:20      5 of 414    M 26-35         2 of 154       00:00:03
#
#     Gun Time            Team
# 4   00:36:24               ]
# 5   00:36:45   INTEL TEAM F]
# ...

# %%
df7['Team']=df7['Team'].str.strip(']')
df7.head()
# Out:
#   Place   Bib                 Name  Gender        City  State  Chip Time  \
# 4     1   814         JARED WILSON       M      TIGARD     OR   00:36:21
# 5     2   573   NATHAN A SUSTERSIC       M    PORTLAND     OR   00:36:42
# 6     3   687       FRANCISCO MAYA       M    PORTLAND     OR   00:37:44
# 7     4   623          PAUL MORROW       M   BEAVERTON     OR   00:38:34
# 8     5   569      DEREK G OSBORNE       M   HILLSBORO     OR   00:39:21
#
#    Chip Pace  Gender Place  Age Group  Age Group Place  Time to Start  \
# 4      05:51      1 of 414    M 36-45         1 of 152       00:00:03
# 5      05:55      2 of 414    M 26-35         1 of 154       00:00:03
# 6      06:05      3 of 414    M 46-55          1 of 64       00:00:04
# 7      06:13      4 of 414    M 36-45         2 of 152       00:00:03
# 8      06:20      5 of 414    M 26-35         2 of 154       00:00:03
#
#     Gun Time           Team
# 4   00:36:24
# 5   00:36:45   INTEL TEAM F
# 6   00:37:48
# 7   00:38:37
# ...

# %% [markdown]
# Data Analysis and Visualization
# The first question to answer is, what was the average finish time (in minutes) for the runners? You need to convert the column "Chip Time" into just minutes.
# One way to do this is to convert the column to a list first for manipulation.

# %%
time_list=df7[' Chip Time'].tolist()
print(time_list[:10])
# Out:
# [' 00:36:21', ' 00:36:42', ' 00:37:44', ' 00:38:34', ' 00:39:21', ' 00:39:49', ' 00:40:04', ' 00:40:05', ' 00:40:17', ' 00:40:21']

# %%
time_mins = []
for i in time_list:
    h, m, s = i.split(':')
    math = (int(h)*60 + int(m) + int(s)/60)
    time_mins.append(math)
#print(time_mins)

# %%
df7['Runner_mins']=time_mins
df7.head()
# Out:
#   Place   Bib                 Name  Gender        City  State  Chip Time  \
# 4     1   814         JARED WILSON       M      TIGARD     OR   00:36:21
# 5     2   573   NATHAN A SUSTERSIC       M    PORTLAND     OR   00:36:42
# 6     3   687       FRANCISCO MAYA       M    PORTLAND     OR   00:37:44
# 7     4   623          PAUL MORROW       M   BEAVERTON     OR   00:38:34
# 8     5   569      DEREK G OSBORNE       M   HILLSBORO     OR   00:39:21
#
#    Chip Pace  Gender Place  Age Group  Age Group Place  Time to Start  \
# 4      05:51      1 of 414    M 36-45         1 of 152       00:00:03
# 5      05:55      2 of 414    M 26-35         1 of 154       00:00:03
# 6      06:05      3 of 414    M 46-55          1 of 64       00:00:04
# 7      06:13      4 of 414    M 36-45         2 of 152       00:00:03
# 8      06:20      5 of 414    M 26-35         2 of 154       00:00:03
#
#     Gun Time           Team  Runner_mins
# 4   00:36:24                   36.350000
# ...

# %%
#The code below shows how to calculate statistics for numeric columns only in the dataframe.
df7.describe(include=[np.number])
# Out:
#        Runner_mins
# count   577.000000
# mean     60.035933
# std      11.970623
# min      36.350000
# 25%      51.000000
# 50%      59.016667
# 75%      67.266667
# max     101.300000

# %% [markdown]
# Interestingly, the average chip time for all runners was ~60 mins. The fastest 10K runner finished in 36.35 mins, and the slowest runner finished in 101.30 minutes.
#
# A boxplot is another useful tool to visualize summary statistics (maximum, minimum, medium, first quartile, third quartile, including outliers). Below are data summary statistics for the runners shown in a boxplot. For data visualization, it is convenient to first import parameters from the pylab module that comes with matplotlib and set the same size for all figures to avoid doing it for each figure.

# %%
from pylab import rcParams
rcParams['figure.figsize']= 15,5

# %%
df7.boxplot(column = 'Runner_mins')
plt.grid(True, axis='y')
plt.ylabel('Chip Time')
plt.xticks([1],['Runners'])
# Out:
# ([<matplotlib.axis.XTick at 0x1e913f254a8>],
#  <a list of 1 Text xticklabel objects>)

# %% [markdown]
# The second question to answer is: Did the runners' finish times follow a normal distribution?
#
# Below is a distribution plot of runners' chip times plotted using the seaborn library. The distribution looks almost normal.

# %%
x = df7['Runner_mins']
ax = sns.distplot(x, hist = True, kde = True, rug = False,color= 'm',bins = 25,hist_kws={'edgecolor':'black'})
plt.show()
# Out:
# C:\Users\Jyoti\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# The third question deals with whether there were any performance differences between males and females of various age groups. Below is a distribution plot of chip times for males and females.

# %%
#f_fuko = df7.loc[df7[' Gender']=='F']['Runner_mins']
#m_fuko = df7.loc[df7[' Gender']=='M']['Runner_mins']

#sns.distplot(f_fuko, hist=True, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Female')
#sns.distplot(m_fuko, hist=False, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Male')
#plt.legend()

# %%
df7.boxplot(column='Runner_mins', by=' Gender')
plt.ylabel('Chip Time')
plt.suptitle("")
# Out:
# Text(0.5,0.98,'')

# %%
g_stats = df7.groupby(" Gender", as_index=True).describe()
print(g_stats)
# Out:
#         Runner_mins                                                         \
#               count       mean        std        min        25%        50%
#  Gender
#  F            163.0  66.119223  12.184440  43.766667  58.758333  64.616667
#  M            414.0  57.640821  11.011857  36.350000  49.395833  55.791667
#
#
#                75%         max
#  Gender
#  F       72.058333  101.300000
#  M       64.804167   98.516667

# %% [markdown]
# In the above project web scraping using Python is performed. The Beautiful Soup library is used to parse html data and convert it into a form that can be used for analysis.Performed cleaning of the data in Python and created useful plots (box plots, bar plots, and distribution plots) to reveal interesting trends using Python's matplotlib and seaborn libraries.
